# %%
from GBM import Brownian
import matplotlib as mpl 
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# -0.         -0.00312601 -0.00625202 -0.00937803 -0.01250405 -0.01563006

# %%
gbm = Brownian()
mu_fn = lambda x: 0.2305
sigma_fn = lambda x: 0.68
pcx = gbm.stock_price(mu_fn=mu_fn, sigma_fn=sigma_fn, deltaT=2400, dt=1)
plt.plot(pcx)

# %%
df = pd.read_csv('sess0001_transactions.csv', names=['trd','t','p'])
arr = np.load('./offset.npy')
print(arr)
fig, ax = plt.subplots(figsize=(12,10))
plt.scatter(df['t'],df['p'], marker='+')
plt.plot(arr+100, color='red')
# Out:
# [  0.          -0.47960609   1.12163267 ... 120.7007038  119.26465113
#  118.51958778]

# %%
df[100:110]
# Out:
#      trd        t    p
# 100  Trd  139.700   96
# 101  Trd  143.275   96
# 102  Trd  143.313  102
# 103  Trd  145.700   96
# 104  Trd  148.100   97
# 105  Trd  148.288   98
# 106  Trd  150.612  100
# 107  Trd  150.650   99
# 108  Trd  150.900   98
# 109  Trd  150.950  103

# %%
arr[149]+100
# Out:
# 89.01944624799263
